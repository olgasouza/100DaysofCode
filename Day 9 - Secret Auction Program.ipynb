# %%
# DAY 9

# %%
# EXERCISE 1 - GRADING PROGRAM (DICTIONARIES)
student_scores = {
  "Harry": 81,
  "Ron": 78,
  "Hermione": 99, 
  "Draco": 74,
  "Neville": 62,
}

student_grades = {}

for name in student_scores:
    if student_scores[name] >= 91:
        student_grades[name] = "Outstanding"
    elif student_scores[name] >= 81:
        student_grades[name] = "Exceeds Expectations"
    elif student_scores[name] >= 71:
        student_grades[name] = "Acceptable"
    else:
        student_grades[name] = "Fail"
    

print(student_grades)

# %%
# EXERCISE 2 - NESTING

# DICTIONARIeS IN DISCTIONARIES
travel_log = {
    "France": {"cities_visited": ["Paris", "Lille", "Dijon"], "number_of_visits": 12},
    "Germany": {"cities_visited": ["Berlin", "Hamburg"], "number_of_visits": 8}
}

# DICTIONARIES IN LISTS (1)
travel_log = [
    {
        "country": "France", 
        "cities_visited": ["Paris", "Lille", "Dijon"], 
        "number_of_visits": 12
        },
    {
        "country": "Germany",
        "cities_visited": ["Berlin", "Hamburg"],
        "number_of_visits": 8
        }
]

# DICTIONARIES IN LISTS (2)
travel_log = [
{
  "country": "France",
  "visits": 12,
  "cities": ["Paris", "Lille", "Dijon"]
},
{
  "country": "Germany",
  "visits": 5,
  "cities": ["Berlin", "Hamburg", "Stuttgart"]
},
]


def add_new_country(name_of_country, number_of_visits, names_of_cities):
    new_dictionary = {}
    new_dictionary["country"] = name_of_country
    new_dictionary["visits"] = number_of_visits
    new_dictionary["cities"] = names_of_cities
    travel_log.append(new_dictionary)


add_new_country("Russia", 2, ["Moscow", "Saint Petersburg"])
print(travel_log)

# %%
# PROJECT 9 - SECRET AUCTION PROGRAM
from subprocess import call
import os

print('''
                         ___________
                         \         /
                          )_______(
                          |"""""""|_.-._,.---------.,_.-._
                          |       | | |               | | ''-.
                          |       |_| |_             _| |_..-'
                          |_______| '-' `'---------'` '-'
                          )"""""""(
                         /_________\\
                       .-------------.
                      /_______________\\
''')

print("\n==== Welcome to the Secret Auction ====\n")
bidders = []

def clear():
    _ = call('clear' if os.name == 'posix' else 'cls')

def add_new_bidder(name_person, value_bid):
    new_dictionary = {}
    new_dictionary["name"] = name_person
    new_dictionary["value"] = value_bid
    bidders.append(new_dictionary)

close_bidding = False
while not close_bidding:
    name = input("What is your name?: ")
    value = int(input("What's your bid?: $"))
    other_bidders = input("Are there any other bidders? Types 'yes' or 'no': ").lower()


    if other_bidders == "no" :
        close_bidding = True
    else:
        clear()

highest_name = ""
highest_value = 0
for item in bidders:
    if item["value"] > highest_value:
        highest_value = item["value"]
        highest_name = item["name"]


print(f"\nThe winner is {highest_name} with a bid of ${highest_value}")

# %%
# PROJECT 9 - TRYING TO REDUCE THE CODE
from subprocess import call
import os

from art import logo
print(logo)
print("\n==== Welcome to the Secret Auction ====\n")

bidders = {}

def clear():
    _ = call('clear' if os.name == 'posix' else 'cls')

close_bidding = False
while not close_bidding:
    name = input("What is your name?: ")
    value = int(input("What's your bid?: $"))
    bidders[name] = value
    other_bidders = input("Are there any other bidders? Types 'yes' or 'no': ").lower()
    if other_bidders == "no" :
        close_bidding = True
    else:
        clear()

highest_name = ""
highest_value = 0
for item in bidders:
    bid_amount = bidders[item]
    if bid_amount > highest_value:
        highest_value = bidders[item]
        highest_name = item


print(f"\nThe winner is {highest_name} with a bid of ${highest_value}")
